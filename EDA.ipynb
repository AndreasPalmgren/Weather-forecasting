# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
# Import dataset
train = pd.read_csv(r'dataset\DailyDelhiClimateTrain.csv', index_col='date')
test = pd.read_csv(r'dataset\DailyDelhiClimateTest.csv', index_col='date')

# %%
train.head()
# train.dtypes
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
# Check for any missing dates - None found
# From 2013-01-01    to    2017-01-01
missing_dates = pd.date_range(start=train.index[0], end=train.index[len(train)-1]).difference(train.index)

# %% [markdown]
# # Plot
# Let us begin by exploring our variables.

# %%
sns.set(rc={'figure.figsize':(11, 8)})
cols_plot = ['meanTemp', 'humidity', 'wind_speed', 'meanpressure']
axes = train.plot(linestyle='None', alpha=0.5, marker='.', subplots = True)
#axes.set_xticklabels([])

# %% [markdown]
# ### Remarks
# * Seasionality within meantemp, humidity and wind_speed.
# * Outlier in meanpreassure. Potential outliers in wind_speed.

# %% [markdown]
# ## Mean temperature

# %%
from scipy import signal

f, Pxx_den = signal.periodogram(train.loc[:, "meantemp"])
plt.semilogy(f, Pxx_den)

# %% [markdown]
# # BREAK POINT?!?
